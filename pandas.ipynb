# %% [markdown]
# <a href="https://colab.research.google.com/github/sikendrapurampravalika-del/ML_LAB_2026-27/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas Python Library**
#
#
# **Introduction to Pandas**
#
#
# Pandas is an open-source software library written for the Python programming language, primarily used for data manipulation and analysis. It provides powerful and flexible data structures designed to make working with tabular and time-series data both easy and intuitive.
#
#
# **Key features and functionalities of Pandas include: Data Structures:**
#
# Pandas introduces two primary data structures:
#
#
# **Series**: A one-dimensional labeled array capable of holding any data type. It can be thought of as a single column in a spreadsheet.
#
# **DataFrame**: A two-dimensional labeled data structure with columns of potentially different data types. It is similar to a spreadsheet or SQL table, providing a powerful way to represent and manipulate tabular data.
#
# **What is pandas used for?**
#
#
# pandas is used throughout the data analysis workflow. With pandas, you can:
#
# Import datasets from databases, spreadsheets, comma-separated values (CSV) files, and more.
# Clean datasets, for example, by dealing with missing values.
# Tidy datasets by reshaping their structure into a suitable format for analysis.
# Aggregate data by calculating summary statistics such as the mean of columns, correlation between them, and more.
# Visualize datasets and uncover insights.

# %% [markdown]
# **Importing data in pandas**

# %%
import pandas as pd

# %%
import pandas as pd
data=pd.read_csv('/content/sample_data/california_housing_train.csv')
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
import pandas as pd
data=pd.read_csv('/content/archive.zip')
data.head()
# Out:
#    student_id  age  gender academic_level  study_hours  self_study_hours  \
# 0           1   23  Female   Postgraduate         1.72              4.53
# 1           2   17   Other  Undergraduate         6.03              4.33
# 2           3   20    Male    High School         1.64              2.07
# 3           4   20    Male  Undergraduate         7.36              3.79
# 4           5   19  Female  Undergraduate         4.23              3.30
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  1.80                2.01          1.50         7.05  ...
# 1                  0.21                0.08          4.06         7.55  ...
# 2                  2.07                3.16          2.78         5.09  ...
# 3                  2.92                1.50          4.66         5.59  ...
# 4                  2.73                4.46          1.73         8.94  ...
#
# ...

# %%
data.tail()
# Out:
#       student_id  age  gender academic_level  study_hours  self_study_hours  \
# 4995        4996   17    Male  Undergraduate         0.60              5.08
# 4996        4997   24    Male    High School         3.11              0.57
# 4997        4998   24  Female  Undergraduate         3.89              3.27
# 4998        4999   24  Female  Undergraduate         3.41              3.06
# 4999        5000   24    Male  Undergraduate         0.89              2.78
#
#       online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# 4995                  0.13                0.94          1.23         8.97
# 4996                  4.06                2.11          4.49         5.75
# 4997                  0.25                0.87          0.00         7.92
# 4998                  3.43                2.17          1.79         4.78
# 4999                  0.82                2.28          0.98         8.90
#
# ...

# %%
data.head()
# Out:
#    student_id  age  gender academic_level  study_hours  self_study_hours  \
# 0           1   23  Female   Postgraduate         1.72              4.53
# 1           2   17   Other  Undergraduate         6.03              4.33
# 2           3   20    Male    High School         1.64              2.07
# 3           4   20    Male  Undergraduate         7.36              3.79
# 4           5   19  Female  Undergraduate         4.23              3.30
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  1.80                2.01          1.50         7.05  ...
# 1                  0.21                0.08          4.06         7.55  ...
# 2                  2.07                3.16          2.78         5.09  ...
# 3                  2.92                1.50          4.66         5.59  ...
# 4                  2.73                4.46          1.73         8.94  ...
#
# ...

# %%
data.student_id
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 4995    4996
# 4996    4997
# 4997    4998
# 4998    4999
# 4999    5000
# Name: student_id, Length: 5000, dtype: int64

# %%
data.count()
# Out:
# student_id              5000
# age                     5000
# gender                  5000
# academic_level          5000
# study_hours             5000
# self_study_hours        5000
# online_classes_hours    5000
# social_media_hours      5000
# gaming_hours            5000
# sleep_hours             5000
# screen_time_hours       5000
# exercise_minutes        5000
# caffeine_intake_mg      5000
# part_time_job           5000
# upcoming_deadline       5000
# internet_quality        5000
# mental_health_score     5000
# focus_index             5000
# burnout_level           5000
# productivity_score      5000
# exam_score              5000
# dtype: int64

# %%
data.describe()
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    21.028000     4.284760          3.240326
# std    1443.520003     2.593407     2.174137          1.595372
# min       1.000000    17.000000     0.500000          0.500000
# 25%    1250.750000    19.000000     2.430000          1.840000
# 50%    2500.500000    21.000000     4.310000          3.250000
# 75%    3750.250000    23.000000     6.170000          4.610000
# max    5000.000000    25.000000     8.000000          6.000000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.488798            2.961974      2.484328     6.494074
# std                1.456146            1.743344      1.444887     1.420291
# min                0.000000            0.000000      0.000000     4.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            5000 non-null   int64
#  1   age                   5000 non-null   int64
#  2   gender                5000 non-null   object
#  3   academic_level        5000 non-null   object
#  4   study_hours           5000 non-null   float64
#  5   self_study_hours      5000 non-null   float64
#  6   online_classes_hours  5000 non-null   float64
#  7   social_media_hours    5000 non-null   float64
#  8   gaming_hours          5000 non-null   float64
#  9   sleep_hours           5000 non-null   float64
#  10  screen_time_hours     5000 non-null   float64
#  11  exercise_minutes      5000 non-null   int64
#  12  caffeine_intake_mg    5000 non-null   int64
#  13  part_time_job         5000 non-null   object
#  14  upcoming_deadline     5000 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['student_id', 'age', 'gender', 'academic_level', 'study_hours',
#        'self_study_hours', 'online_classes_hours', 'social_media_hours',
#        'gaming_hours', 'sleep_hours', 'screen_time_hours', 'exercise_minutes',
#        'caffeine_intake_mg', 'part_time_job', 'upcoming_deadline',
#        'internet_quality', 'mental_health_score', 'focus_index',
#        'burnout_level', 'productivity_score', 'exam_score'],
#       dtype='object')

# %%
df3=pd.read_excel('/content/file_example_XLS_50.xls')
df3
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
df3.columns
# Out:
# Index([0, 'First Name', 'Last Name', 'Gender', 'Country', 'Age', 'Date', 'Id'], dtype='object')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   0           50 non-null     int64
#  1   First Name  50 non-null     object
#  2   Last Name   50 non-null     object
#  3   Gender      50 non-null     object
#  4   Country     50 non-null     object
#  5   Age         50 non-null     int64
#  6   Date        50 non-null     object
#  7   Id          50 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 3.3+ KB

# %%
df3.describe()
# Out:
#               0        Age           Id
# count  50.00000  50.000000    50.000000
# mean   25.50000  33.260000  4717.720000
# std    14.57738   8.434163  2391.188783
# min     1.00000  21.000000  1258.000000
# 25%    13.25000  26.250000  2603.750000
# 50%    25.50000  32.000000  3574.000000
# 75%    37.75000  37.750000  6536.250000
# max    50.00000  58.000000  9654.000000

# %%
df3.count()
# Out:
# 0             50
# First Name    50
# Last Name     50
# Gender        50
# Country       50
# Age           50
# Date          50
# Id            50
# dtype: int64

# %%
df3.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
df3.tail()
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 45  46       Roma  Lafollette  Female  United States   34  15/10/2017  2654
# 46  47     Felisa        Cail  Female  United States   28  16/08/2016  6525
# 47  48   Demetria       Abbey  Female  United States   32  21/05/2015  3265
# 48  49     Jeromy        Danz    Male  United States   39  15/10/2017  3265
# 49  50   Rasheeda      Alkire  Female  United States   29  16/08/2016  6125
